# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeshchag/AI/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2021-11-02 at 10.25.13 PM.jpeg](data:image/jpeg;base64,...)

# %%
x=2;
eta=0.001
eps=0.000001
delx=1
max_iter=10000
iter=0
def deriv(x):
  xderive=4*x*x*x+6*x
  return xderive

# %%
while abs(delx)>eps and iter<max_iter:
    prevx=x;
    delx=-eta*deriv(prevx)
    x=x+delx
    iter=iter+1
print("Value of local minimum occurs at ",round(x))
obj=x*x*x*x+3*x*x+10
print("Value of objective function = ",round(obj))
# Out:
# Value of local minimum occurs at  0
# Value of objective function =  10
